# %%
# Import the random module
import pandas as pd
import matplotlib.pyplot as plt
import random
import numpy as np
import requests

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
x = 1
latitudes = []
while x < 11:
    random_lat = random.randint(-90, 89) + random.random()
    latitudes.append(random_lat)
    x += 1

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 2000
# %timeit latitudes(2000)
# Out:
# 2.55 ms ± 41.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a list for holding the cities.
cities = []


# Identify nearest city for each latitude and longitude combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 728

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []



# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["sys"]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | yellowknife
# Processing Record 3 of Set 1 | kodiak
# Processing Record 4 of Set 1 | yulara
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | narsaq
# Processing Record 7 of Set 1 | namibe
# Processing Record 8 of Set 1 | arraial do cabo
# Processing Record 9 of Set 1 | scarborough
# Processing Record 10 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 1 | cornwall
# Processing Record 12 of Set 1 | mecca
# Processing Record 13 of Set 1 | lodwar
# Processing Record 14 of Set 1 | dikson
# Processing Record 15 of Set 1 | butaritari
# Processing Record 16 of Set 1 | temaraia
# City not found. Skipping...
# Processing Record 17 of Set 1 | onzaga
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | nanortalik
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | nome
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | carnarvon
# Processing Record 25 of Set 1 | yumen
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | klaksvik
# Processing Record 28 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 1 | mayo
# Processing Record 31 of Set 1 | bulungu
# Processing Record 32 of Set 1 | hambantota
# Processing Record 33 of Set 1 | ribeira grande
# Processing Record 34 of Set 1 | saskylakh
# Processing Record 35 of Set 1 | tandil
# Processing Record 36 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 1 | kuytun
# Processing Record 38 of Set 1 | barrow
# Processing Record 39 of Set 1 | vila
# Processing Record 40 of Set 1 | kendari
# Processing Record 41 of Set 1 | qasigiannguit
# Processing Record 42 of Set 1 | port hardy
# Processing Record 43 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 1 | castro
# Processing Record 45 of Set 1 | ojinaga
# Processing Record 46 of Set 1 | hurricane
# Processing Record 47 of Set 1 | tiksi
# Processing Record 48 of Set 1 | cabo san lucas
# Processing Record 49 of Set 1 | kinlochleven
# Processing Record 50 of Set 1 | tasiilaq
# Processing Record 1 of Set 2 | yerbogachen
# Processing Record 2 of Set 2 | leningradskiy
# Processing Record 3 of Set 2 | volginskiy
# City not found. Skipping...
# Processing Record 4 of Set 2 | jamestown
# Processing Record 5 of Set 2 | aloja
# Processing Record 6 of Set 2 | buraydah
# Processing Record 7 of Set 2 | brokopondo
# Processing Record 8 of Set 2 | qaanaaq
# Processing Record 9 of Set 2 | east london
# Processing Record 10 of Set 2 | sakakah
# Processing Record 11 of Set 2 | soderhamn
# Processing Record 12 of Set 2 | houma
# Processing Record 13 of Set 2 | saldanha
# Processing Record 14 of Set 2 | belaya gora
# Processing Record 15 of Set 2 | chandur bazar
# Processing Record 16 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 2 | hofn
# Processing Record 18 of Set 2 | sitka
# Processing Record 19 of Set 2 | souillac
# Processing Record 20 of Set 2 | atuona
# Processing Record 21 of Set 2 | bartica
# Processing Record 22 of Set 2 | port victoria
# Processing Record 23 of Set 2 | nador
# Processing Record 24 of Set 2 | bambanglipuro
# Processing Record 25 of Set 2 | mogadouro
# Processing Record 26 of Set 2 | lazaro cardenas
# Processing Record 27 of Set 2 | chokurdakh
# Processing Record 28 of Set 2 | brandon
# Processing Record 29 of Set 2 | saint-augustin
# Processing Record 30 of Set 2 | ambilobe
# Processing Record 31 of Set 2 | torbay
# Processing Record 32 of Set 2 | barranca
# Processing Record 33 of Set 2 | husavik
# Processing Record 34 of Set 2 | kusk
# City not found. Skipping...
# Processing Record 35 of Set 2 | ringsted
# Processing Record 36 of Set 2 | catia la mar
# Processing Record 37 of Set 2 | mataura
# Processing Record 38 of Set 2 | port alfred
# Processing Record 39 of Set 2 | chumikan
# Processing Record 40 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 2 | araouane
# Processing Record 42 of Set 2 | avarua
# Processing Record 43 of Set 2 | marystown
# Processing Record 44 of Set 2 | maceio
# Processing Record 45 of Set 2 | port elizabeth
# Processing Record 46 of Set 2 | monterey
# Processing Record 47 of Set 2 | saint-pierre
# Processing Record 48 of Set 2 | najran
# Processing Record 49 of Set 2 | bengkulu
# Processing Record 50 of Set 2 | paamiut
# Processing Record 1 of Set 3 | albany
# Processing Record 2 of Set 3 | lebu
# Processing Record 3 of Set 3 | kavieng
# Processing Record 4 of Set 3 | bolshaya izhora
# Processing Record 5 of Set 3 | new norfolk
# Processing Record 6 of Set 3 | tuktoyaktuk
# Processing Record 7 of Set 3 | flinders
# Processing Record 8 of Set 3 | kyren
# Processing Record 9 of Set 3 | jumla
# Processing Record 10 of Set 3 | hobart
# Processing Record 11 of Set 3 | cape town
# Processing Record 12 of Set 3 | itoman
# Processing Record 13 of Set 3 | kribi
# Processing Record 14 of Set 3 | kaitangata
# Processing Record 15 of Set 3 | fort nelson
# Processing Record 16 of Set 3 | axim
# Processing Record 17 of Set 3 | lubao
# Processing Record 18 of Set 3 | hailar
# Processing Record 19 of Set 3 | kochubey
# Processing Record 20 of Set 3 | tacuati
# Processing Record 21 of Set 3 | adrar
# Processing Record 22 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 23 of Set 3 | richards bay
# Processing Record 24 of Set 3 | paarl
# Processing Record 25 of Set 3 | aklavik
# Processing Record 26 of Set 3 | ostrovnoy
# Processing Record 27 of Set 3 | isangel
# Processing Record 28 of Set 3 | hithadhoo
# Processing Record 29 of Set 3 | misratah
# Processing Record 30 of Set 3 | nouadhibou
# Processing Record 31 of Set 3 | tiznit
# Processing Record 32 of Set 3 | rawson
# Processing Record 33 of Set 3 | ponta do sol
# Processing Record 34 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 35 of Set 3 | ust-barguzin
# Processing Record 36 of Set 3 | cap malheureux
# Processing Record 37 of Set 3 | ketchikan
# Processing Record 38 of Set 3 | bredasdorp
# Processing Record 39 of Set 3 | severo-kurilsk
# Processing Record 40 of Set 3 | lorengau
# Processing Record 41 of Set 3 | bluff
# Processing Record 42 of Set 3 | mackenzie
# Processing Record 43 of Set 3 | bongandanga
# Processing Record 44 of Set 3 | hilo
# Processing Record 45 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 3 | college
# Processing Record 47 of Set 3 | sao filipe
# Processing Record 48 of Set 3 | churapcha
# Processing Record 49 of Set 3 | evensk
# Processing Record 50 of Set 3 | westport
# Processing Record 1 of Set 4 | ulladulla
# Processing Record 2 of Set 4 | lappeenranta
# Processing Record 3 of Set 4 | puerto ayora
# Processing Record 4 of Set 4 | bantry
# Processing Record 5 of Set 4 | riyadh
# Processing Record 6 of Set 4 | shar
# Processing Record 7 of Set 4 | palimbang
# Processing Record 8 of Set 4 | pietermaritzburg
# Processing Record 9 of Set 4 | talnakh
# Processing Record 10 of Set 4 | san quintin
# Processing Record 11 of Set 4 | kulhudhuffushi
# Processing Record 12 of Set 4 | wagar
# Processing Record 13 of Set 4 | barro
# Processing Record 14 of Set 4 | aketi
# Processing Record 15 of Set 4 | san cristobal
# Processing Record 16 of Set 4 | dezhou
# Processing Record 17 of Set 4 | lixourion
# Processing Record 18 of Set 4 | morant bay
# Processing Record 19 of Set 4 | alta floresta
# Processing Record 20 of Set 4 | gwadar
# Processing Record 21 of Set 4 | hualmay
# Processing Record 22 of Set 4 | ancud
# Processing Record 23 of Set 4 | bronnoysund
# Processing Record 24 of Set 4 | pareora
# Processing Record 25 of Set 4 | georgetown
# Processing Record 26 of Set 4 | madzhalis
# Processing Record 27 of Set 4 | broome
# Processing Record 28 of Set 4 | half moon bay
# Processing Record 29 of Set 4 | kimparana
# Processing Record 30 of Set 4 | lompoc
# Processing Record 31 of Set 4 | ushtobe
# Processing Record 32 of Set 4 | asau
# Processing Record 33 of Set 4 | guerrero negro
# Processing Record 34 of Set 4 | suez
# Processing Record 35 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 4 | provideniya
# Processing Record 37 of Set 4 | sukhoverkovo
# City not found. Skipping...
# Processing Record 38 of Set 4 | saint-philippe
# Processing Record 39 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 40 of Set 4 | lufilufi
# Processing Record 41 of Set 4 | kupang
# Processing Record 42 of Set 4 | clyde river
# Processing Record 43 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 4 | marawi
# Processing Record 45 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 4 | byron bay
# Processing Record 47 of Set 4 | prince rupert
# Processing Record 48 of Set 4 | tianpeng
# Processing Record 49 of Set 4 | ostersund
# Processing Record 50 of Set 4 | lata
# Processing Record 1 of Set 5 | vestmannaeyjar
# Processing Record 2 of Set 5 | hovd
# Processing Record 3 of Set 5 | cherskiy
# Processing Record 4 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 5 of Set 5 | bandarbeyla
# Processing Record 6 of Set 5 | olinda
# Processing Record 7 of Set 5 | oussouye
# Processing Record 8 of Set 5 | uberaba
# Processing Record 9 of Set 5 | mogadishu
# Processing Record 10 of Set 5 | katobu
# Processing Record 11 of Set 5 | lipin bor
# Processing Record 12 of Set 5 | san miguel
# Processing Record 13 of Set 5 | savannah bight
# City not found. Skipping...
# Processing Record 14 of Set 5 | puerto narino
# Processing Record 15 of Set 5 | laval
# Processing Record 16 of Set 5 | sacama
# Processing Record 17 of Set 5 | airai
# Processing Record 18 of Set 5 | thompson
# Processing Record 19 of Set 5 | ushibuka
# Processing Record 20 of Set 5 | iqaluit
# Processing Record 21 of Set 5 | burica
# City not found. Skipping...
# Processing Record 22 of Set 5 | albemarle
# Processing Record 23 of Set 5 | bambous virieux
# Processing Record 24 of Set 5 | cidreira
# Processing Record 25 of Set 5 | iroquois falls
# Processing Record 26 of Set 5 | custoias
# Processing Record 27 of Set 5 | khasan
# Processing Record 28 of Set 5 | kaeo
# Processing Record 29 of Set 5 | sault sainte marie
# Processing Record 30 of Set 5 | barentu
# Processing Record 31 of Set 5 | mar del plata
# Processing Record 32 of Set 5 | vanimo
# Processing Record 33 of Set 5 | omsukchan
# Processing Record 34 of Set 5 | oranjemund
# Processing Record 35 of Set 5 | naze
# Processing Record 36 of Set 5 | khudumelapye
# Processing Record 37 of Set 5 | qom
# Processing Record 38 of Set 5 | dingle
# Processing Record 39 of Set 5 | port lincoln
# Processing Record 40 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 42 of Set 5 | nikolskoye
# Processing Record 43 of Set 5 | gornyy
# Processing Record 44 of Set 5 | kikwit
# Processing Record 45 of Set 5 | longjiang
# Processing Record 46 of Set 5 | berlevag
# Processing Record 47 of Set 5 | payson
# Processing Record 48 of Set 5 | vallenar
# Processing Record 49 of Set 5 | beringovskiy
# Processing Record 50 of Set 5 | cap-aux-meules
# Processing Record 1 of Set 6 | atar
# Processing Record 2 of Set 6 | zhigansk
# Processing Record 3 of Set 6 | miragoane
# Processing Record 4 of Set 6 | cooma
# Processing Record 5 of Set 6 | caboolture
# Processing Record 6 of Set 6 | charters towers
# Processing Record 7 of Set 6 | chapais
# Processing Record 8 of Set 6 | mount gambier
# Processing Record 9 of Set 6 | lida
# Processing Record 10 of Set 6 | wau
# Processing Record 11 of Set 6 | huazolotitlan
# City not found. Skipping...
# Processing Record 12 of Set 6 | ilulissat
# Processing Record 13 of Set 6 | gunjur
# Processing Record 14 of Set 6 | norman wells
# Processing Record 15 of Set 6 | henties bay
# Processing Record 16 of Set 6 | hobyo
# Processing Record 17 of Set 6 | khatanga
# Processing Record 18 of Set 6 | sinazongwe
# Processing Record 19 of Set 6 | halifax
# Processing Record 20 of Set 6 | cowra
# Processing Record 21 of Set 6 | madera
# Processing Record 22 of Set 6 | howard springs
# Processing Record 23 of Set 6 | chuy
# Processing Record 24 of Set 6 | qaqortoq
# Processing Record 25 of Set 6 | tabuk
# Processing Record 26 of Set 6 | inirida
# Processing Record 27 of Set 6 | sola
# Processing Record 28 of Set 6 | loudeac
# Processing Record 29 of Set 6 | buala
# Processing Record 30 of Set 6 | auki
# Processing Record 31 of Set 6 | lemoore
# Processing Record 32 of Set 6 | avera
# Processing Record 33 of Set 6 | te anau
# Processing Record 34 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 35 of Set 6 | bilma
# Processing Record 36 of Set 6 | eureka
# Processing Record 37 of Set 6 | mabaruma
# Processing Record 38 of Set 6 | tilichiki
# Processing Record 39 of Set 6 | opunake
# Processing Record 40 of Set 6 | emerald
# Processing Record 41 of Set 6 | dublin
# Processing Record 42 of Set 6 | tommot
# Processing Record 43 of Set 6 | vardo
# Processing Record 44 of Set 6 | alice springs
# Processing Record 45 of Set 6 | arua
# Processing Record 46 of Set 6 | egvekinot
# Processing Record 47 of Set 6 | vilhena
# Processing Record 48 of Set 6 | pasighat
# Processing Record 49 of Set 6 | hirara
# Processing Record 50 of Set 6 | sistranda
# Processing Record 1 of Set 7 | rawalpindi
# Processing Record 2 of Set 7 | faanui
# Processing Record 3 of Set 7 | bahia honda
# Processing Record 4 of Set 7 | banda aceh
# Processing Record 5 of Set 7 | kafanchan
# Processing Record 6 of Set 7 | coquimbo
# Processing Record 7 of Set 7 | ugoofaaru
# Processing Record 8 of Set 7 | seoul
# Processing Record 9 of Set 7 | hasaki
# Processing Record 10 of Set 7 | tromso
# Processing Record 11 of Set 7 | saint george
# Processing Record 12 of Set 7 | elliot
# Processing Record 13 of Set 7 | mesyagutovo
# Processing Record 14 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 15 of Set 7 | kununurra
# Processing Record 16 of Set 7 | constitucion
# Processing Record 17 of Set 7 | chatellerault
# Processing Record 18 of Set 7 | yangmei
# Processing Record 19 of Set 7 | talakan
# Processing Record 20 of Set 7 | taloqan
# Processing Record 21 of Set 7 | sibolga
# Processing Record 22 of Set 7 | baykit
# Processing Record 23 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 7 | sioux lookout
# Processing Record 25 of Set 7 | svetlogorsk
# Processing Record 26 of Set 7 | miraflores
# Processing Record 27 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 28 of Set 7 | george
# Processing Record 29 of Set 7 | tortoli
# Processing Record 30 of Set 7 | majene
# Processing Record 31 of Set 7 | necochea
# Processing Record 32 of Set 7 | porto belo
# Processing Record 33 of Set 7 | macas
# Processing Record 34 of Set 7 | urulga
# City not found. Skipping...
# Processing Record 35 of Set 7 | hartford
# Processing Record 36 of Set 7 | ndele
# Processing Record 37 of Set 7 | gamba
# Processing Record 38 of Set 7 | ballina
# Processing Record 39 of Set 7 | sisimiut
# Processing Record 40 of Set 7 | syracuse
# Processing Record 41 of Set 7 | mentok
# City not found. Skipping...
# Processing Record 42 of Set 7 | kieta
# Processing Record 43 of Set 7 | finale ligure
# Processing Record 44 of Set 7 | asyut
# Processing Record 45 of Set 7 | mineral wells
# Processing Record 46 of Set 7 | la paz
# Processing Record 47 of Set 7 | san patricio
# Processing Record 48 of Set 7 | ixtapa
# Processing Record 49 of Set 7 | qurayyat
# Processing Record 50 of Set 7 | mahebourg
# Processing Record 1 of Set 8 | katsuura
# Processing Record 2 of Set 8 | ciudad bolivar
# Processing Record 3 of Set 8 | quibdo
# Processing Record 4 of Set 8 | ponyri
# Processing Record 5 of Set 8 | smithers
# Processing Record 6 of Set 8 | oyama
# Processing Record 7 of Set 8 | abu dhabi
# Processing Record 8 of Set 8 | emba
# Processing Record 9 of Set 8 | ust-maya
# Processing Record 10 of Set 8 | hayden
# Processing Record 11 of Set 8 | port arthur
# Processing Record 12 of Set 8 | kez
# Processing Record 13 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 14 of Set 8 | victoria
# Processing Record 15 of Set 8 | cervo
# Processing Record 16 of Set 8 | kamenka
# Processing Record 17 of Set 8 | bethel
# Processing Record 18 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 8 | ankang
# Processing Record 20 of Set 8 | kutum
# Processing Record 21 of Set 8 | malindi
# Processing Record 22 of Set 8 | camacha
# Processing Record 23 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 24 of Set 8 | mahon
# Processing Record 25 of Set 8 | vao
# Processing Record 26 of Set 8 | kirakira
# Processing Record 27 of Set 8 | iralaya
# Processing Record 28 of Set 8 | longyearbyen
# Processing Record 29 of Set 8 | banposh
# Processing Record 30 of Set 8 | mardin
# Processing Record 31 of Set 8 | labuhan
# Processing Record 32 of Set 8 | esperance
# Processing Record 33 of Set 8 | pinawa
# Processing Record 34 of Set 8 | urzhum
# Processing Record 35 of Set 8 | celestun
# Processing Record 36 of Set 8 | jinchang
# Processing Record 37 of Set 8 | ust-koksa
# Processing Record 38 of Set 8 | mnogovershinnyy
# Processing Record 39 of Set 8 | koundara
# Processing Record 40 of Set 8 | leshukonskoye
# Processing Record 41 of Set 8 | mayumba
# Processing Record 42 of Set 8 | libohove
# Processing Record 43 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 44 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 45 of Set 8 | bac lieu
# Processing Record 46 of Set 8 | farafangana
# Processing Record 47 of Set 8 | slobodskoy
# Processing Record 48 of Set 8 | ville-marie
# Processing Record 49 of Set 8 | pontes e lacerda
# Processing Record 50 of Set 8 | pustoshka
# Processing Record 1 of Set 9 | linjiang
# Processing Record 2 of Set 9 | dekar
# Processing Record 3 of Set 9 | codrington
# Processing Record 4 of Set 9 | sapele
# Processing Record 5 of Set 9 | sturgis
# Processing Record 6 of Set 9 | moerai
# Processing Record 7 of Set 9 | beloha
# Processing Record 8 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 9 | katherine
# Processing Record 10 of Set 9 | lebedinyy
# Processing Record 11 of Set 9 | liloy
# Processing Record 12 of Set 9 | kotelnikovo
# Processing Record 13 of Set 9 | pevek
# Processing Record 14 of Set 9 | caravelas
# Processing Record 15 of Set 9 | pacifica
# Processing Record 16 of Set 9 | viedma
# Processing Record 17 of Set 9 | diego de almagro
# Processing Record 18 of Set 9 | wajima
# Processing Record 19 of Set 9 | omboue
# Processing Record 20 of Set 9 | nuevo progreso
# Processing Record 21 of Set 9 | praia
# Processing Record 22 of Set 9 | pafos
# Processing Record 23 of Set 9 | upornaya
# Processing Record 24 of Set 9 | geraldton
# Processing Record 25 of Set 9 | aksarka
# Processing Record 26 of Set 9 | pangai
# Processing Record 27 of Set 9 | zhireken
# Processing Record 28 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 29 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 9 | sweetwater
# Processing Record 31 of Set 9 | vostok
# Processing Record 32 of Set 9 | bonfim
# Processing Record 33 of Set 9 | kahului
# Processing Record 34 of Set 9 | alihe
# Processing Record 35 of Set 9 | fairbanks
# Processing Record 36 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 37 of Set 9 | lavrentiya
# Processing Record 38 of Set 9 | grindavik
# Processing Record 39 of Set 9 | gao
# Processing Record 40 of Set 9 | redmond
# Processing Record 41 of Set 9 | sao joao da barra
# Processing Record 42 of Set 9 | bowen
# Processing Record 43 of Set 9 | port-gentil
# Processing Record 44 of Set 9 | xuddur
# Processing Record 45 of Set 9 | birobidzhan
# Processing Record 46 of Set 9 | sibut
# Processing Record 47 of Set 9 | nishihara
# Processing Record 48 of Set 9 | krasnoselkup
# Processing Record 49 of Set 9 | laguna
# Processing Record 50 of Set 9 | harper
# Processing Record 1 of Set 10 | zinder
# Processing Record 2 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 10 | chaplynka
# Processing Record 4 of Set 10 | akyab
# Processing Record 5 of Set 10 | samarai
# Processing Record 6 of Set 10 | maple creek
# Processing Record 7 of Set 10 | komsomolskiy
# Processing Record 8 of Set 10 | pisco
# Processing Record 9 of Set 10 | bahua
# Processing Record 10 of Set 10 | mohpa
# Processing Record 11 of Set 10 | ngunguru
# Processing Record 12 of Set 10 | veraval
# Processing Record 13 of Set 10 | porbandar
# Processing Record 14 of Set 10 | novobirilyussy
# Processing Record 15 of Set 10 | chapelle-lez-herlaimont
# Processing Record 16 of Set 10 | alyangula
# Processing Record 17 of Set 10 | svetlaya
# Processing Record 18 of Set 10 | inhambane
# Processing Record 19 of Set 10 | bubaque
# Processing Record 20 of Set 10 | aksarayskiy
# Processing Record 21 of Set 10 | ambon
# Processing Record 22 of Set 10 | victor harbor
# Processing Record 23 of Set 10 | denison
# Processing Record 24 of Set 10 | erice
# Processing Record 25 of Set 10 | balakhta
# Processing Record 26 of Set 10 | tulle
# Processing Record 27 of Set 10 | placido de castro
# Processing Record 28 of Set 10 | okhotsk
# Processing Record 29 of Set 10 | almonte
# Processing Record 30 of Set 10 | kenora
# Processing Record 31 of Set 10 | ilinskiy
# Processing Record 32 of Set 10 | rosetta
# Processing Record 33 of Set 10 | winslow
# Processing Record 34 of Set 10 | mehran
# Processing Record 35 of Set 10 | mazagao
# Processing Record 36 of Set 10 | bereda
# Processing Record 37 of Set 10 | poum
# Processing Record 38 of Set 10 | sitges
# Processing Record 39 of Set 10 | marly
# Processing Record 40 of Set 10 | faya
# Processing Record 41 of Set 10 | baherden
# Processing Record 42 of Set 10 | sorland
# Processing Record 43 of Set 10 | padang
# Processing Record 44 of Set 10 | nova vicosa
# Processing Record 45 of Set 10 | mingshui
# Processing Record 46 of Set 10 | high prairie
# Processing Record 47 of Set 10 | krasnaya gora
# Processing Record 48 of Set 10 | tunduru
# City not found. Skipping...
# Processing Record 49 of Set 10 | luderitz
# Processing Record 50 of Set 10 | biak
# Processing Record 1 of Set 11 | koppang
# Processing Record 2 of Set 11 | hamilton
# Processing Record 3 of Set 11 | vila velha
# Processing Record 4 of Set 11 | le port
# Processing Record 5 of Set 11 | ponta delgada
# Processing Record 6 of Set 11 | santa rosa
# Processing Record 7 of Set 11 | kranuan
# Processing Record 8 of Set 11 | kailua
# Processing Record 9 of Set 11 | oxbow
# Processing Record 10 of Set 11 | hernani
# Processing Record 11 of Set 11 | whyalla
# Processing Record 12 of Set 11 | gold coast
# Processing Record 13 of Set 11 | itarema
# Processing Record 14 of Set 11 | phonhong
# Processing Record 15 of Set 11 | buenos aires
# Processing Record 16 of Set 11 | wakkanai
# Processing Record 17 of Set 11 | kapasan
# Processing Record 18 of Set 11 | tomatlan
# Processing Record 19 of Set 11 | erzin
# Processing Record 20 of Set 11 | deputatskiy
# Processing Record 21 of Set 11 | touros
# Processing Record 22 of Set 11 | praya
# Processing Record 23 of Set 11 | cockburn town
# Processing Record 24 of Set 11 | marsh harbour
# Processing Record 25 of Set 11 | oranjestad
# Processing Record 26 of Set 11 | tambura
# Processing Record 27 of Set 11 | hearst
# Processing Record 28 of Set 11 | benjamin constant
# Processing Record 29 of Set 11 | semme
# Processing Record 30 of Set 11 | karratha
# Processing Record 31 of Set 11 | yanchukan
# City not found. Skipping...
# Processing Record 32 of Set 11 | anchorage
# Processing Record 33 of Set 11 | tura
# Processing Record 34 of Set 11 | valdepenas
# Processing Record 35 of Set 11 | dzaoudzi
# Processing Record 36 of Set 11 | stryn
# Processing Record 37 of Set 11 | upernavik
# Processing Record 38 of Set 11 | meulaboh
# Processing Record 39 of Set 11 | puerto escondido
# Processing Record 40 of Set 11 | altamira
# Processing Record 41 of Set 11 | norden
# Processing Record 42 of Set 11 | shush
# Processing Record 43 of Set 11 | kozhva
# Processing Record 44 of Set 11 | hami
# Processing Record 45 of Set 11 | alofi
# Processing Record 46 of Set 11 | gondanglegi
# Processing Record 47 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 48 of Set 11 | manadhoo
# Processing Record 49 of Set 11 | skjervoy
# Processing Record 50 of Set 11 | say
# Processing Record 1 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 12 | flin flon
# Processing Record 3 of Set 12 | shaoyang
# Processing Record 4 of Set 12 | frontignan
# Processing Record 5 of Set 12 | guimar
# Processing Record 6 of Set 12 | yar-sale
# Processing Record 7 of Set 12 | homer
# Processing Record 8 of Set 12 | toyooka
# Processing Record 9 of Set 12 | vila franca do campo
# Processing Record 10 of Set 12 | grand gaube
# Processing Record 11 of Set 12 | eisiskes
# Processing Record 12 of Set 12 | honningsvag
# Processing Record 13 of Set 12 | nelson bay
# Processing Record 14 of Set 12 | noumea
# Processing Record 15 of Set 12 | daru
# Processing Record 16 of Set 12 | wigtown
# Processing Record 17 of Set 12 | port antonio
# Processing Record 18 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 12 | coulihaut
# City not found. Skipping...
# Processing Record 20 of Set 12 | kedrovyy
# Processing Record 21 of Set 12 | shaunavon
# Processing Record 22 of Set 12 | port hedland
# Processing Record 23 of Set 12 | trelew
# Processing Record 24 of Set 12 | raga
# Processing Record 25 of Set 12 | oriximina
# Processing Record 26 of Set 12 | gimli
# Processing Record 27 of Set 12 | port blair
# Processing Record 28 of Set 12 | hay river
# Processing Record 29 of Set 12 | pangnirtung
# Processing Record 30 of Set 12 | anloga
# Processing Record 31 of Set 12 | jennings
# Processing Record 32 of Set 12 | kuzino
# Processing Record 33 of Set 12 | upata
# Processing Record 34 of Set 12 | covington
# Processing Record 35 of Set 12 | yeppoon
# Processing Record 36 of Set 12 | bossembele
# City not found. Skipping...
# Processing Record 37 of Set 12 | shieli
# Processing Record 38 of Set 12 | klyuchi
# Processing Record 39 of Set 12 | nyurba
# Processing Record 40 of Set 12 | srednekolymsk
# Processing Record 41 of Set 12 | ilheus
# Processing Record 42 of Set 12 | monticello
# Processing Record 43 of Set 12 | tres de maio
# Processing Record 44 of Set 12 | turukhansk
# Processing Record 45 of Set 12 | road town
# Processing Record 46 of Set 12 | tobol
# Processing Record 47 of Set 12 | udachnyy
# Processing Record 48 of Set 12 | kenai
# Processing Record 49 of Set 12 | cockburn harbour
# City not found. Skipping...
# Processing Record 50 of Set 12 | kalabo
# Processing Record 1 of Set 13 | colinas
# Processing Record 2 of Set 13 | shelburne
# Processing Record 3 of Set 13 | huejuquilla el alto
# Processing Record 4 of Set 13 | wegorzewo
# Processing Record 5 of Set 13 | ulaanbaatar
# Processing Record 6 of Set 13 | mundo nuevo
# Processing Record 7 of Set 13 | ariano irpino
# Processing Record 8 of Set 13 | parana
# Processing Record 9 of Set 13 | bardiyah
# Processing Record 10 of Set 13 | milledgeville
# Processing Record 11 of Set 13 | clinton
# Processing Record 12 of Set 13 | brae
# Processing Record 13 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 13 | ukiah
# Processing Record 15 of Set 13 | korla
# Processing Record 16 of Set 13 | roebourne
# Processing Record 17 of Set 13 | erenhot
# Processing Record 18 of Set 13 | wundanyi
# Processing Record 19 of Set 13 | tashtyp
# Processing Record 20 of Set 13 | kruisfontein
# Processing Record 21 of Set 13 | himora
# City not found. Skipping...
# Processing Record 22 of Set 13 | taoudenni
# Processing Record 23 of Set 13 | cobija
# Processing Record 24 of Set 13 | dong hoi
# Processing Record 25 of Set 13 | fortuna
# Processing Record 26 of Set 13 | jaciara
# Processing Record 27 of Set 13 | eldikan
# City not found. Skipping...
# Processing Record 28 of Set 13 | iguape
# Processing Record 29 of Set 13 | namatanai
# Processing Record 30 of Set 13 | douglas
# Processing Record 31 of Set 13 | juneau
# Processing Record 32 of Set 13 | westpunt
# City not found. Skipping...
# Processing Record 33 of Set 13 | belomorsk
# Processing Record 34 of Set 13 | tottori
# Processing Record 35 of Set 13 | chesma
# Processing Record 36 of Set 13 | follonica
# Processing Record 37 of Set 13 | umm lajj
# Processing Record 38 of Set 13 | haines junction
# Processing Record 39 of Set 13 | raudeberg
# Processing Record 40 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 41 of Set 13 | pathalgaon
# Processing Record 42 of Set 13 | vyborg
# Processing Record 43 of Set 13 | beyneu
# Processing Record 44 of Set 13 | parit buntar
# Processing Record 45 of Set 13 | skelleftea
# Processing Record 46 of Set 13 | tamala
# Processing Record 47 of Set 13 | bonavista
# Processing Record 48 of Set 13 | huarmey
# Processing Record 49 of Set 13 | kokstad
# Processing Record 50 of Set 13 | maloshuyka
# City not found. Skipping...
# Processing Record 1 of Set 14 | sambava
# Processing Record 2 of Set 14 | sedro-woolley
# Processing Record 3 of Set 14 | arona
# Processing Record 4 of Set 14 | kalininsk
# Processing Record 5 of Set 14 | cayenne
# Processing Record 6 of Set 14 | nanchong
# Processing Record 7 of Set 14 | san lawrenz
# Processing Record 8 of Set 14 | ambikapur
# Processing Record 9 of Set 14 | tsienyane
# City not found. Skipping...
# Processing Record 10 of Set 14 | acarau
# Processing Record 11 of Set 14 | korsor
# Processing Record 12 of Set 14 | dali
# Processing Record 13 of Set 14 | salalah
# Processing Record 14 of Set 14 | aripuana
# Processing Record 15 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 16 of Set 14 | qandala
# Processing Record 17 of Set 14 | mehamn
# Processing Record 18 of Set 14 | san lorenzo
# Processing Record 19 of Set 14 | deniliquin
# Processing Record 20 of Set 14 | mbale
# Processing Record 21 of Set 14 | antalaha
# Processing Record 22 of Set 14 | shingu
# Processing Record 23 of Set 14 | el retorno
# Processing Record 24 of Set 14 | rumphi
# Processing Record 25 of Set 14 | eyl
# Processing Record 26 of Set 14 | maldonado
# Processing Record 27 of Set 14 | aliwal north
# Processing Record 28 of Set 14 | sabang
# Processing Record 29 of Set 14 | ust-ilimsk
# Processing Record 30 of Set 14 | santa maria
# Processing Record 31 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 32 of Set 14 | nadym
# Processing Record 33 of Set 14 | taksimo
# Processing Record 34 of Set 14 | kefamenanu
# Processing Record 35 of Set 14 | northport
# Processing Record 36 of Set 14 | los llanos de aridane
# Processing Record 37 of Set 14 | almansa
# Processing Record 38 of Set 14 | cianorte
# Processing Record 39 of Set 14 | khromtau
# Processing Record 40 of Set 14 | novyy urengoy
# Processing Record 41 of Set 14 | umm kaddadah
# Processing Record 42 of Set 14 | hirado
# Processing Record 43 of Set 14 | berani
# Processing Record 44 of Set 14 | jiangyou
# Processing Record 45 of Set 14 | timoteo
# Processing Record 46 of Set 14 | uk
# City not found. Skipping...
# Processing Record 47 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 48 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 49 of Set 14 | purranque
# Processing Record 50 of Set 14 | kuliyapitiya
# Processing Record 1 of Set 15 | tangwani
# Processing Record 2 of Set 15 | mlowo
# Processing Record 3 of Set 15 | altoona
# Processing Record 4 of Set 15 | port augusta
# Processing Record 5 of Set 15 | tokoroa
# Processing Record 6 of Set 15 | manzanillo
# Processing Record 7 of Set 15 | praia da vitoria
# Processing Record 8 of Set 15 | andra
# Processing Record 9 of Set 15 | karaton
# Processing Record 10 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 11 of Set 15 | pangody
# Processing Record 12 of Set 15 | mahibadhoo
# Processing Record 13 of Set 15 | mujiayingzi
# Processing Record 14 of Set 15 | motozintla
# Processing Record 15 of Set 15 | big spring
# Processing Record 16 of Set 15 | nyuksenitsa
# Processing Record 17 of Set 15 | pitimbu
# Processing Record 18 of Set 15 | feijo
# Processing Record 19 of Set 15 | lodja
# Processing Record 20 of Set 15 | gravdal
# Processing Record 21 of Set 15 | namie
# Processing Record 22 of Set 15 | lagoa
# Processing Record 23 of Set 15 | manokwari
# Processing Record 24 of Set 15 | pascagoula
# Processing Record 25 of Set 15 | kegayli
# City not found. Skipping...
# Processing Record 26 of Set 15 | vega de alatorre
# Processing Record 27 of Set 15 | den helder
# Processing Record 28 of Set 15 | bathsheba
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Punta Arenas      CL -53.1500  -70.9167     46.51        66          75
# 1      Yellowknife      CA  62.4560 -114.3525     28.92        46           0
# 2           Kodiak      US  57.7900 -152.4072     42.31        65          40
# 3           Yulara      AU -25.2406  130.9889     71.44        26           6
# 4          Ushuaia      AR -54.8000  -68.3000     42.46        81          40
# 5           Narsaq      GL  60.9167  -46.0500     35.82        62         100
# 6           Namibe      AO -15.1961   12.1522     77.40        80          99
# 7  Arraial Do Cabo      BR -22.9661  -42.0278     73.47        76           4
# 8      Scarborough      GB  54.2797   -0.4044     40.64        88          51
# 9         Cornwall      CA  45.0181  -74.7281     39.25        70           0
#
#    Wind Speed
# 0       11.50
# 1        6.91
# 2        6.91
# 3       17.27
# 4       24.16
# 5        3.65
# 6        4.76
# 7        9.28
# 8        5.66
# 9        6.91

# %%
city_data_df.to_csv('WeatherPy_Database.csv')
